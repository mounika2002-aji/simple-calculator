# %%
import numpy as np
import matplotlib.pyplot as plt
ran=np.random.randn(15,3)
colors=["red","green","orange"]
plt.hist(ran,bins=20,density=True,histtype='bar',color=colors,edgecolor='Black')
plt.savefig('E:/first.png')
plt.show()

# %%
x=[1,3,4,4,6,7,7,9,10,11,11,12,12,12,14,15]
ran=[0,6,11,15]
plt.hist(x,20,edgecolor="red",color='white')
# Out:
# (array([1., 0., 1., 0., 2., 0., 0., 1., 2., 0., 0., 1., 1., 0., 2., 3., 0.,
#         0., 1., 1.]),
#  array([ 1. ,  1.7,  2.4,  3.1,  3.8,  4.5,  5.2,  5.9,  6.6,  7.3,  8. ,
#          8.7,  9.4, 10.1, 10.8, 11.5, 12.2, 12.9, 13.6, 14.3, 15. ]),
#  <BarContainer object of 20 artists>)

# %%
odd=[1,3,5,7,9]
even=[2,4,6,8,10]
plt.hist(odd,color="green",edgrcolor="white")
plt.hist(even,color="
# Out:
# (array([2., 2., 2., 2., 2.]),
#  array([ 1. ,  2.8,  4.6,  6.4,  8.2, 10. ]),
#  <BarContainer object of 5 artists>)
